# %%
import matplotlib.pyplot as plt
import matplotlib.image as pltimg
im = pltimg.imread('.\\6_26.jpg')
fig = plt.figure(figsize=(15,10))
plt.subplot(221)
plt.imshow(im[:,:,0])
plt.subplot(222)
plt.imshow(im[:,:,1])
plt.subplot(223)
plt.imshow(im[:,:,2])
plt.subplot(224)
plt.imshow(im)
plt.show()

# %%
im = pltimg.imread('.\\6_26.jpg')
fig = plt.figure()
plt.subplot(121)
plt.plot(im[:,1000,1])
plt.subplot(122)
plt.imshow(im)
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as pltimg
im = pltimg.imread('6_26.jpg')
fig = plt.figure(figsize=(20, 20))
plt.subplot(221)
head = im[240:570,900:1200]
building = im[0:200, 0:250]
plt.imshow(im)
plt.subplot(222)
plt.imshow(head)
plt.subplot(223)
plt.imshow(building)
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as pltimg
im = pltimg.imread('6_26.jpg')
im1 = pltimg.imread('6_26.jpg')
im2 = pltimg.imread('6_26.jpg')
im3 = pltimg.imread('6_26.jpg')
fig = plt.figure(figsize=(15,10))

plt.subplot(331)
plt.imshow(im)

im1[:, :, 1] = im[:, :, 2]
plt.subplot(332)
plt.imshow(im1)

im2[:, :, 1] = im[:, :, 0]
plt.subplot(333)
plt.imshow(im2)

im3[:, :, 0] = im[:, :, 2]
plt.subplot(334)
plt.imshow(im3)

plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as pltimg
im = pltimg.imread('6_26.jpg')
fig = plt.figure(figsize=(15,10))
head = im[240:570,900:1200]

im[0:330, 0:300] = head

plt.subplot(221)
plt.imshow(head)

plt.subplot(222)
plt.imshow(im)

plt.show()
